# %%
from ete3 import Tree

# %%
camel_virus = 'MN514967.1_Dromedary_camel_coronavirus_HKU23_isolate_DcCoV-HKU23/camel/Nigeria/NV1385/2016'

# %%
initial_tree = Tree('../4/tree.txt', format=1)

# %%
print(initial_tree)
# Out:
#       /-OK017858.1_Sarbecovirus_sp._isolate_YN2020H
#      |
#      |      /-MK211375.1_Coronavirus_BtRs-BetaCoV/YN2018A
#      |   /-|
#      |  |   \-KY417144.1_Bat_SARS-like_coronavirus_isolate_Rs4084
#      |  |
#      |  |               /-MT308984.1_Mutant_SARS_coronavirus_Urbani_clone_SARS-Urbani-MA_SHC014-spike
#      |  |            /-|
#      |  |         /-|   \-MK062183.1_SARS_coronavirus_Urbani_isolate_icSARS-C7
#      |  |        |  |
#      |  |      /-|   \-KP886808.1_Bat_SARS-like_coronavirus_YNLF_31C
#      |  |     |  |
#      |  |     |  |   /-JX993988.1_Bat_coronavirus_Cp/Yunnan2011
#      |  |     |   \-|
#      |  |     |     |   /-MZ081382.1_Betacoronavirus_sp._RsYN09_strain_bat/Yunnan/RsYN09/2020
#      |  |     |      \-|
#      |  |     |        |   /-KF569996.1_Rhinolophus_affinis_coronavirus_isolate_LYRa11
#      |  |     |         \-|
#      |  |     |            \-MZ081377.1_Betacoronavirus_sp._RmYN07_strain_bat/Yunnan/RmYN07/2020
#      |  |     |
# ...

# %%
initial_tree.set_outgroup(camel_virus)

# %%
print(initial_tree)
# Out:
#    /-MN514967.1_Dromedary_camel_coronavirus_HKU23_isolate_DcCoV-HKU23/camel/Nigeria/NV1385/2016
#   |
#   |         /-LC556375.1_Severe_acute_respiratory_syndrome-related_coronavirus_Rc-o319_RNA
#   |        |
#   |      /-|   /-MZ081376.1_Betacoronavirus_sp._RmYN05_strain_bat/Yunnan/RmYN05/2020
#   |     |  |  |
#   |     |   \-|   /-MT040335.1_Pangolin_coronavirus_isolate_PCoV_GX-P5L
#   |     |     |  |
#   |     |      \-|   /-MT121216.1_Pangolin_coronavirus_isolate_MP789
#   |     |        |  |
#   |     |        |  |      /-OK017805.1_Sarbecovirus_sp._isolate_HN2021G
#   |     |         \-|   /-|
#   |     |           |  |  |   /-OK017803.1_Sarbecovirus_sp._isolate_HN2021A
#   |     |           |  |   \-|
#   |     |           |  |     |   /-MG772933.1_Bat_SARS-like_coronavirus_isolate_bat-SL-CoVZC45
#   |     |            \-|      \-|
#   |     |              |         \-MG772934.1_Bat_SARS-like_coronavirus_isolate_bat-SL-CoVZXC21
#   |     |              |
# ...
